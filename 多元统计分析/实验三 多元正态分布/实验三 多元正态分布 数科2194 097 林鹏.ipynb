# %% [markdown]
# <center><h1>实验三 多元正态分布</h1></center>

# %% [markdown]
# ## 姓名：林鹏&emsp;&emsp;班级：数科2194&emsp;&emsp;学号：202141084097

# %% [markdown]
# ### 一、简单描述统计量

# %%
import numpy as np
import pandas as pd

# %%
examp3_4_2 = pd.read_excel('./examp3.4.2.xlsx', header=[0]) # 从带分割符的文本文件中导入数据，第一行为变量名
# Out:
# d:\Anaconda3\lib\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")

# %%
examp3_4_2.head(2)  # 列出数据框的前 2 行
# Out:
#    年龄     体重     肺活量  1.5英里跑的时间  休息时的脉搏  跑步时的脉搏  跑步时的最大脉搏
# 0  44  89.47  44.609      11.37      62     178       182
# 1  40  75.07  45.313      10.07      62     185       185

# %%
examp3_4_2.describe()   # 计算五数概括及均值
# Out:
#               年龄         体重        肺活量  1.5英里跑的时间     休息时的脉搏      跑步时的脉搏  \
# count  31.000000  31.000000  31.000000  31.000000  31.000000   31.000000
# mean   47.677419  77.444516  47.375806  10.586129  53.741935  169.645161
# std     5.211443   8.328568   5.327231   1.387414   8.294447   10.251986
# min    38.000000  59.080000  37.388000   8.170000  40.000000  146.000000
# 25%    44.000000  73.200000  44.964500   9.780000  48.000000  163.000000
# 50%    48.000000  77.450000  46.774000  10.470000  52.000000  170.000000
# 75%    51.000000  82.325000  50.131000  11.270000  58.500000  176.000000
# max    57.000000  91.630000  60.055000  14.030000  76.000000  186.000000
#
#          跑步时的最大脉搏
# count   31.000000
# mean   173.774194
# std      9.164095
# min    155.000000
# 25%    168.000000
# 50%    172.000000
# 75%    180.000000
# max    192.000000

# %%
examp3_4_2.std(axis=0)  # 计算标准差
# Out:
# 年龄            5.211443
# 体重            8.328568
# 肺活量           5.327231
# 1.5英里跑的时间     1.387414
# 休息时的脉搏        8.294447
# 跑步时的脉搏       10.251986
# 跑步时的最大脉搏      9.164095
# dtype: float64

# %% [markdown]
# ### 二、作相关分析

# %% [markdown]
# #### (一)协方差矩阵和相关性矩阵

# %%
from scipy import stats

# %%
Sigma = examp3_4_2.cov()    # 计算协方差矩阵
Sigma.round(4)  # 保留 4 位小数
# Out:
#                 年龄       体重      肺活量  1.5英里跑的时间   休息时的脉搏    跑步时的脉搏  跑步时的最大脉搏
# 年龄         27.1591 -10.1365  -8.4563     1.3647  -6.1194  -18.0516  -20.6753
# 体重        -10.1365  69.3650  -7.2211     1.6583   1.5682   15.4987   19.0337
# 肺活量        -8.4563  -7.2211  28.3794    -6.3725 -15.3064  -21.7352  -11.5575
# 1.5英里跑的时间   1.3647   1.6583  -6.3725     1.9249   4.6093    4.4612    2.8748
# 休息时的脉搏     -6.1194   1.5682 -15.3064     4.6093  68.7978   27.0387   19.5731
# 跑步时的脉搏    -18.0516  15.4987 -21.7352     4.4612  27.0387  105.1032   87.3505
# 跑步时的最大脉搏  -20.6753  19.0337 -11.5575     2.8748  19.5731   87.3505   83.9806

# %%
rho = examp3_4_2.corr() # 计算相关矩阵
rho.round(4)
# Out:
#                年龄      体重     肺活量  1.5英里跑的时间  休息时的脉搏  跑步时的脉搏  跑步时的最大脉搏
# 年龄         1.0000 -0.2335 -0.3046     0.1887 -0.1416 -0.3379   -0.4329
# 体重        -0.2335  1.0000 -0.1628     0.1435  0.0227  0.1815    0.2494
# 肺活量       -0.3046 -0.1628  1.0000    -0.8622 -0.3464 -0.3980   -0.2367
# 1.5英里跑的时间  0.1887  0.1435 -0.8622     1.0000  0.4005  0.3136    0.2261
# 休息时的脉搏    -0.1416  0.0227 -0.3464     0.4005  1.0000  0.3180    0.2575
# 跑步时的脉搏    -0.3379  0.1815 -0.3980     0.3136  0.3180  1.0000    0.9298
# 跑步时的最大脉搏  -0.4329  0.2494 -0.2367     0.2261  0.2575  0.9298    1.0000

# %% [markdown]
# ### 三、散点图矩阵和旋转图

# %%
from pylab import mpl
import seaborn as sns

# %% [markdown]
# #### (一)散点图矩阵

# %%
mpl.rcParams["font.sans-serif"] = ["SimHei"]
sns.pairplot(examp3_4_2)

# %% [markdown]
# #### （二）旋转图

# %%
import matplotlib.pyplot as plt
examp3_4_2.head()
# Out:
#    年龄     体重     肺活量  1.5英里跑的时间  休息时的脉搏  跑步时的脉搏  跑步时的最大脉搏
# 0  44  89.47  44.609      11.37      62     178       182
# 1  40  75.07  45.313      10.07      62     185       185
# 2  44  85.84  54.297       8.65      45     156       168
# 3  42  68.15  59.571       8.17      40     166       172
# 4  38  89.02  49.874       9.22      55     178       180

# %%
#创建⼀个⻓为10，宽为7的图
fig = plt.figure(figsize = (10, 7))
#创建⼀个3D⽴体图
ax = plt.axes(projection ="3d")
#输⼊数据
ax.scatter3D(examp3_4_2['年龄'], examp3_4_2['体重'], examp3_4_2['肺活量'])
#填写x,y,z轴轴标及命名标题
ax.set_xlabel('年龄')
ax.set_ylabel('体重')
ax.set_zlabel('肺活量')
plt.title("旋转图") 
plt.show()

# %% [markdown]
# ### 四、正态随机数的产生

# %%
np.random.normal(size=30).round(3)  # 产生30个标准正态分布的随机数，保留3位小数
# Out:
# array([ 0.642, -0.736,  0.097, -1.226,  0.649,  0.322,  0.636, -1.138,
#        -0.406, -0.969,  2.325, -1.747,  1.84 , -1.334, -1.358, -0.273,
#        -0.678, -1.86 , -0.244, -0.398,  1.753, -1.081, -0.683,  1.211,
#        -0.023, -0.663, -0.453, -0.604, -2.028, -0.344])

# %%
np.random.normal(loc=20, scale=6**2, size=10).round(3)  # 产生10个均值为20，标准差为6的正态分布随机数
# Out:
# array([ -0.342,  39.483, -17.805,  39.627, -23.234, -30.268,  -9.828,
#         21.634, -31.769,  36.241])

# %%
mean = np.array([3, 1, 4])  # 指定均值矩阵

# %%
sigma = np.array([6, 1, -2, 1, 13, 4, -2, 4, 4]).reshape(3,3)   # 指定协方差矩阵

# %%
np.random.multivariate_normal(mean, sigma, 5)   # 生成5个三元正态分布的随机数
# Out:
# array([[ 3.15574122,  9.46326782,  5.27155879],
#        [ 2.8395807 ,  6.81912651,  7.02997564],
#        [ 5.94284062, -2.2857347 , -0.0930129 ],
#        [ 1.16760924,  3.82006729,  5.60107261],
#        [ 2.27859   , -4.65500246,  3.28024733]])

# %% [markdown]
# ### 五、补充：

# %% [markdown]
# #### 1、说明“五数概况”指的是哪五种指标，及这些指标的含义，当原数据中包含缺失值时，这五数概况是如何处理的

# %% [markdown]
# > 五数概括指的是最小值，第一分位数，中位数，均值，第三分位数，最大值
#
# > 含义分别为：样本中最小的数，样本中第一个1/4的数，中间数，平均值，样本中第三个1/4的数，样本中最大的数
#
# > 当原数据中包含缺失值时，这五数概括直接忽略缺失值

# %% [markdown]
# #### 2、由协方差矩阵查看7个随机变量中方差最大的是哪一个，协方差最大的是哪一对；在相关系数矩阵中它们的相关系数还是最大的吗？

# %%
value = np.diag(Sigma)
col = Sigma.columns
sigma = pd.Series(data=value,index=col)
sigma.idxmax()
# Out:
# '跑步时的脉搏'

# %% [markdown]
# > 方差最大的是"跑步时的脉搏"

# %%
max_sigma = Sigma.copy()
np.fill_diagonal(max_sigma.values, 0)
max_sigma.stack().idxmax()
# Out:
# ('跑步时的脉搏', '跑步时的最大脉搏')

# %% [markdown]
# > 协方差矩阵最大的一组是(跑步时的脉搏，跑步时的最大脉搏)

# %%
max_rho = rho.copy()
np.fill_diagonal(max_rho.values, 0)
max_rho.stack().idxmax()
# Out:
# ('跑步时的脉搏', '跑步时的最大脉搏')

# %% [markdown]
# > 在相关系数矩阵中它们的相关系数还是最大

# %% [markdown]
# #### 3、实现单独求x1和x2的协方差和相关系数

# %%
df12 = examp3_4_2.iloc[:,[0, 1]]
df12.cov().iloc[0,1].round(4)
# Out:
# -10.1365

# %% [markdown]
# > x1和x2的协方差为-10.1365

# %%
df12.corr().iloc[0,1].round(4)
# Out:
# -0.2335

# %% [markdown]
# > x1和x2的相关系数为-0.2335

# %% [markdown]
# #### 4、实现将生成的5个三元正态分布的随机数计算其均值和协方差矩阵，它们与文中的mean和sigma是否相同，为什么

# %%
mean = (3, 1, 4)
sigma = np.array([6, 1, -2, 1, 13, 4, -2, 4, 4]).reshape(3,3, order='F')
rd = np.random.multivariate_normal(mean, sigma, (5)).round(4)
rd
# Out:
# array([[ 4.4832,  4.6825,  3.5864],
#        [ 0.2637, -3.5286,  3.1   ],
#        [ 0.9548, -4.0772,  1.7609],
#        [ 3.5315,  2.2346,  1.5521],
#        [-1.8474, -0.6549,  5.6779]])

# %%
rd_mean = rd.mean().round(4)
rd_mean
# Out:
# 1.448

# %%
rd_Sigma = np.cov(rd).round(4)
rd_Sigma
# Out:
# array([[ 0.3409, -1.7608, -1.3542,  0.3775, -2.2421],
#        [-1.7608, 11.0607, 10.0113, -0.87  ,  9.7999],
#        [-1.3542, 10.0113, 10.009 ,  0.1577,  6.1728],
#        [ 0.3775, -0.87  ,  0.1577,  1.011 , -3.4607],
#        [-2.2421,  9.7999,  6.1728, -3.4607, 16.3594]])

# %% [markdown]
# > 与文中的mean和Sigma不同，因为文中的mean是Sigma是总体的，这里的是样本的

# %% [markdown]
# #### 5、实现examp3.4.2的数据标准化（Z标准化），在标准化前后都求一次协方差矩阵和相关系数矩阵，查看标准化后的数据是否存在协方差矩阵和相关系数矩阵一致的情况。

# %%
# 标准化前
before_Sigma = examp3_4_2.cov()
before_rho =  examp3_4_2.corr()
before_rho
# Out:
#                  年龄        体重       肺活量  1.5英里跑的时间    休息时的脉搏    跑步时的脉搏  \
# 年龄         1.000000 -0.233539 -0.304592   0.188745 -0.141566 -0.337870
# 体重        -0.233539  1.000000 -0.162753   0.143508  0.022701  0.181516
# 肺活量       -0.304592 -0.162753  1.000000  -0.862195 -0.346405 -0.397974
# 1.5英里跑的时间  0.188745  0.143508 -0.862195   1.000000  0.400536  0.313648
# 休息时的脉搏    -0.141566  0.022701 -0.346405   0.400536  1.000000  0.317973
# 跑步时的脉搏    -0.337870  0.181516 -0.397974   0.313648  0.317973  1.000000
# 跑步时的最大脉搏  -0.432916  0.249381 -0.236740   0.226103  0.257503  0.929754
#
#            跑步时的最大脉搏
# 年龄        -0.432916
# 体重         0.249381
# 肺活量       -0.236740
# 1.5英里跑的时间  0.226103
# 休息时的脉搏     0.257503
# 跑步时的脉搏     0.929754
# 跑步时的最大脉搏   1.000000

# %%
from sklearn import preprocessing
# 标准化
z_score = preprocessing.scale(examp3_4_2.values)
z_score = pd.DataFrame(z_score, columns=examp3_4_2.columns)

# %%
# 标准化后
after_Sigma = z_score.cov()
after_Sigma
# Out:
#                  年龄        体重       肺活量  1.5英里跑的时间    休息时的脉搏    跑步时的脉搏  \
# 年龄         1.033333 -0.241324 -0.314745   0.195037 -0.146285 -0.349133
# 体重        -0.241324  1.033333 -0.168178   0.148291  0.023458  0.187567
# 肺活量       -0.314745 -0.168178  1.033333  -0.890935 -0.357952 -0.411240
# 1.5英里跑的时间  0.195037  0.148291 -0.890935   1.033333  0.413887  0.324103
# 休息时的脉搏    -0.146285  0.023458 -0.357952   0.413887  1.033333  0.328572
# 跑步时的脉搏    -0.349133  0.187567 -0.411240   0.324103  0.328572  1.033333
# 跑步时的最大脉搏  -0.447346  0.257694 -0.244632   0.233640  0.266087  0.960746
#
#            跑步时的最大脉搏
# 年龄        -0.447346
# 体重         0.257694
# 肺活量       -0.244632
# 1.5英里跑的时间  0.233640
# 休息时的脉搏     0.266087
# 跑步时的脉搏     0.960746
# 跑步时的最大脉搏   1.033333

# %%
after_rho = z_score.corr()
after_rho
# Out:
#                  年龄        体重       肺活量  1.5英里跑的时间    休息时的脉搏    跑步时的脉搏  \
# 年龄         1.000000 -0.233539 -0.304592   0.188745 -0.141566 -0.337870
# 体重        -0.233539  1.000000 -0.162753   0.143508  0.022701  0.181516
# 肺活量       -0.304592 -0.162753  1.000000  -0.862195 -0.346405 -0.397974
# 1.5英里跑的时间  0.188745  0.143508 -0.862195   1.000000  0.400536  0.313648
# 休息时的脉搏    -0.141566  0.022701 -0.346405   0.400536  1.000000  0.317973
# 跑步时的脉搏    -0.337870  0.181516 -0.397974   0.313648  0.317973  1.000000
# 跑步时的最大脉搏  -0.432916  0.249381 -0.236740   0.226103  0.257503  0.929754
#
#            跑步时的最大脉搏
# 年龄        -0.432916
# 体重         0.249381
# 肺活量       -0.236740
# 1.5英里跑的时间  0.226103
# 休息时的脉搏     0.257503
# 跑步时的脉搏     0.929754
# 跑步时的最大脉搏   1.000000

# %%
np.allclose(before_Sigma, after_Sigma)
# Out:
# False

# %% [markdown]
# > 协方差矩阵不同

# %%
np.allclose(before_rho, after_rho)
# Out:
# True

# %% [markdown]
# > 相关矩阵相同
